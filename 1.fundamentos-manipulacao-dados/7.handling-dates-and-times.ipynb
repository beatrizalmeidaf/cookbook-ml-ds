# %% [markdown]
# # Handling Dates and Times

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ## Converter strings para datas

# %%
date_strings = np.array(['03-04-2005 11:35 PM',
                    '23-05-2010 12:01 AM',
                    '04-09-2009 09:09 PM'])

[pd.to_datetime(date, format='%d-%m-%Y %I:%M %p', errors='coerce') for date in strings]
# Out:
# [Timestamp('2005-04-03 23:35:00'),
#  Timestamp('2010-05-23 00:01:00'),
#  Timestamp('2009-09-04 21:09:00')]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Selecionando Datas

# %%
dataframe = pd.DataFrame()

dataframe['date'] = pd.date_range('1/1/2001', periods=100000, freq='H')
dataframe
# Out:
# C:\Users\BeatrizAlmeida\AppData\Local\Temp\ipykernel_16932\513090617.py:3: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   dataframe['date'] = pd.date_range('1/1/2001', periods=100000, freq='H')
#                      date
# 0     2001-01-01 00:00:00
# 1     2001-01-01 01:00:00
# 2     2001-01-01 02:00:00
# 3     2001-01-01 03:00:00
# 4     2001-01-01 04:00:00
# ...                   ...
# 99995 2012-05-29 11:00:00
# 99996 2012-05-29 12:00:00
# 99997 2012-05-29 13:00:00
# 99998 2012-05-29 14:00:00
# 99999 2012-05-29 15:00:00
#
# [100000 rows x 1 columns]

# %%
dataframe[(dataframe['date'] > '2002-1-1 01:00:00') &
 (dataframe['date'] <= '2002-1-1 04:00:00')]
# Out:
#                     date
# 8762 2002-01-01 02:00:00
# 8763 2002-01-01 03:00:00
# 8764 2002-01-01 04:00:00

# %% [markdown]
# ## Separando Datas em Múltiplas Features

# %%
dataframe = pd.DataFrame()

dataframe['date'] = pd.date_range('1/1/2001', periods=150, freq='W')

dataframe['year'] = dataframe['date'].dt.year
dataframe['month'] = dataframe['date'].dt.month
dataframe['day'] = dataframe['date'].dt.day
dataframe['hour'] = dataframe['date'].dt.hour
dataframe['minute'] = dataframe['date'].dt.minute

dataframe.head(3)
# Out:
#         date  year  month  day  hour  minute
# 0 2001-01-07  2001      1    7     0       0
# 1 2001-01-14  2001      1   14     0       0
# 2 2001-01-21  2001      1   21     0       0

# %% [markdown]
# ## Lidando com Valores Nulos/Ausentes

# %%
time_index = pd.date_range("01/01/2010", periods=5, freq="M")

dataframe = pd.DataFrame(index=time_index)

dataframe["Sales"] = [1.0,2.0,np.nan,np.nan,5.0]
# interpolação
dataframe.interpolate()
# Out:
# C:\Users\BeatrizAlmeida\AppData\Local\Temp\ipykernel_16932\3662453136.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   time_index = pd.date_range("01/01/2010", periods=5, freq="M")
#             Sales
# 2010-01-31    1.0
# 2010-02-28    2.0
# 2010-03-31    3.0
# 2010-04-30    4.0
# 2010-05-31    5.0
