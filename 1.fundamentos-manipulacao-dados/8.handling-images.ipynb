# %% [markdown]
# # Handling Images

# %%
# !pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    --- ------------------------------------ 3.4/39.5 MB 24.1 MB/s eta 0:00:02
#    -------- ------------------------------- 8.7/39.5 MB 24.1 MB/s eta 0:00:02
#    --------------- ------------------------ 14.9/39.5 MB 26.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 22.3/39.5 MB 28.4 MB/s eta 0:00:01
#    ------------------------------ --------- 30.4/39.5 MB 30.4 MB/s eta 0:00:01
#    ------------------------------------- -- 36.7/39.5 MB 30.6 MB/s eta 0:00:01
#    ---------------------------------------- 39.5/39.5 MB 28.5 MB/s eta 0:00:00
# ...

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

cv2.__version__
# Out:
# '4.11.0'

# %%
image = cv2.imread('data/images.jpeg', cv2.IMREAD_GRAYSCALE)

plt.imshow(image, cmap='gray'), plt.axis("off")
plt.show()

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image
# Out:
# array([[ 58,  59,  59, ...,  52,  52,  52],
#        [ 59,  59,  59, ...,  53,  53,  52],
#        [ 59,  59,  60, ...,  54,  54,  53],
#        ...,
#        [209, 214, 222, ..., 199, 199, 199],
#        [208, 212, 218, ..., 196, 196, 196],
#        [207, 209, 213, ..., 194, 194, 193]], shape=(183, 275), dtype=uint8)

# %%
image.shape
# Out:
# (183, 275)

# %%
# primeiro pixel 
image[0,0]
# Out:
# np.uint8(58)

# %%
image_bgr = cv2.imread("data/images.jpeg", cv2.IMREAD_COLOR)

image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb), plt.axis("off")
plt.show()

# %% [markdown]
# ## Mudando Tamanho

# %%
image = cv2.imread("data/images.jpeg", cv2.IMREAD_GRAYSCALE)

image_50x50 = cv2.resize(image, (50, 50))

plt.imshow(image_50x50, cmap="gray"), plt.axis("off")
plt.show()

# %%
image_cropped = image[:,:128]

plt.imshow(image_cropped, cmap="gray"), plt.axis("off")
plt.show()

# %%
image_blurry = cv2.blur(image, (5,5))

plt.imshow(image_blurry, cmap="gray"), plt.axis("off")
plt.show()

# %%
kernel = np.array([[0, -1, 0],
                   [-1, 5,-1],
                   [0, -1, 0]])

image_sharp = cv2.filter2D(image, -1, kernel)

plt.imshow(image_sharp, cmap="gray"), plt.axis("off")
plt.show()

# %% [markdown]
# ## Criando Features para Machine Learning

# %%
image = cv2.imread("data/images.jpeg", cv2.IMREAD_GRAYSCALE)

image = cv2.resize(image, (10,10))
image.flatten() # converte a imagem para um vetor unidirecional
# Out:
# array([ 68,  65,  69,  73,  72,  73,  74,  71,  67,  71,  74,  76,  78,
#         80,  81,  81,  82,  81,  81,  86,  85,  98, 105, 108, 108, 108,
#        105, 104, 102,  98,  93, 101, 104, 107, 142, 103, 104, 101,  97,
#         99, 107, 112, 116, 121, 108, 121, 120, 121, 116, 113, 118, 217,
#         50,  70,  65,  62,  78, 133, 127, 119, 131, 138, 142, 143, 157,
#        158, 158, 160, 160, 155, 149, 144, 189, 175, 230, 241, 232, 146,
#        147, 148, 158, 148, 228, 204, 182, 240, 215, 207, 217, 205, 192,
#        174, 204, 216, 201, 195, 204, 196, 220, 215], dtype=uint8)

# %%
plt.imshow(image, cmap="gray"), plt.axis("off")
plt.show()

# %%
image.shape
# Out:
# (10, 10)

# %%
image.flatten().shape
# Out:
# (100,)
